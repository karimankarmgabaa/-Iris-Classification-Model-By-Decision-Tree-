# %% [markdown]
# # <strong><i><font color='brouwn'>Wellcome In 3th Task In The Sparks Foundation Intern </font></i></strong>
# ## my_name:Kariman Karm Gabaa
# # <font color='gray'>'Iris' Classification Model By Decision Tree Classifier</font>

# %% [markdown]
# ### <font color='red'>1- Exploring data</font>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn.datasets as Data
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree

# %%
dt=Data.load_iris()
data=pd.DataFrame(dt.data,columns=dt.feature_names)
data.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
y=dt.target

# %%
classifier=DecisionTreeClassifier()
classifier.fit(data,y)
print("complete")
# Out:
# complete

# %%
fig = plt.figure(figsize=(25,20))
_ = tree.plot_tree(classifier, 
                   feature_names=dt.feature_names,  
                   class_names=dt.target_names,
                   filled=True)
